# %%
from IPython.display import Image
# %matplotlib inline

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.5.3.56-cp36-cp36m-win_amd64.whl (34.9 MB)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\khali\appdata\roaming\python\python36\site-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.3.56
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: You are using pip version 21.0.1; however, version 21.2.1 is available.
# You should consider upgrading via the 'C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ##  Preprocessing/Exploration/Inspection des valeurs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
data_dir = "./Class1_def"
#la dataset d image pour yosra

# %%
# !pip install xmltodict
#installation de normes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xmltodict in c:\users\khali\appdata\roaming\python\python36\site-packages (0.12.0)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: You are using pip version 21.0.1; however, version 21.2.1 is available.
# You should consider upgrading via the 'C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\python.exe -m pip install --upgrade pip' command.

# %%
from coslib import plot_ellipse_seg_test

plot_ellipse_seg_test(os.path.join(data_dir, "1.png"))

# %%
from coslib import load_images_masks

# %%
X, y = load_images_masks(data_dir, img_type='png', img_format='gray', resize=(512, 512), ellipse=True)

# %%
X.shape
# Out:
# (150, 512, 512, 1)

# %%
y.shape
# Out:
# (150, 512, 512, 1)

# %%
plt.imshow(X[0,:,:,0], cmap='gray')

# %%
plt.imshow(y[0,:,:,0], cmap='gray')

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape
# Out:
# (105, 512, 512, 1)

# %%
X_test.shape
# Out:
# (45, 512, 512, 1)

# %%
img_rows = 512
img_cols = 512

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Lambda, Conv2DTranspose, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from scipy.ndimage.measurements import label
import time

# %%
# Defining a small Unet
# Smaller Unet defined so it fits in memory


def get_small_unet():
    inputs = Input((img_rows, img_cols, 1))
    inputs_norm = Lambda(lambda x: x/127.5 - 1.)
    conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(64, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(128, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(32, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(64, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(16, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(32, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(8, kernel_size=(
        2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(16, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=inputs, outputs=conv10)

    return model

# %%
model = get_small_unet()

# %%
def smooth_dice_coeff(smooth=1.):

    smooth = float(smooth)

    # IOU or dice coeff calculation
    def IOU_calc(y_true, y_pred):
            y_true_f = K.flatten(y_true)
            y_pred_f = K.flatten(y_pred)
            intersection = K.sum(y_true_f * y_pred_f)

            return 2*(intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

    def IOU_calc_loss(y_true, y_pred):
        return -IOU_calc(y_true, y_pred)
    return IOU_calc, IOU_calc_loss

IOU_calc, IOU_calc_loss = smooth_dice_coeff(0.00001)

# %%
model.compile(optimizer=Adam(lr=1e-4), loss=IOU_calc_loss, metrics=[IOU_calc])

# %%
history = model.fit(X_train, y_train, batch_size=10, epochs=50, verbose=1, validation_split=0.1)
# Out:
# Train on 94 samples, validate on 11 samples
# Epoch 1/50
# 94/94 [==============================] - 21s 228ms/sample - loss: -0.0741 - IOU_calc: 0.0744 - val_loss: -0.0985 - val_IOU_calc: 0.1306
# Epoch 2/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.0785 - IOU_calc: 0.0787 - val_loss: -0.1046 - val_IOU_calc: 0.0873
# Epoch 3/50
# 94/94 [==============================] - 6s 67ms/sample - loss: -0.0868 - IOU_calc: 0.0881 - val_loss: -0.1216 - val_IOU_calc: 0.1033
# Epoch 4/50
# 94/94 [==============================] - 6s 67ms/sample - loss: -0.1164 - IOU_calc: 0.1191 - val_loss: -0.1912 - val_IOU_calc: 0.1949
# Epoch 5/50
# 94/94 [==============================] - 6s 67ms/sample - loss: -0.2190 - IOU_calc: 0.2192 - val_loss: -0.2458 - val_IOU_calc: 0.2094
# Epoch 6/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.2868 - IOU_calc: 0.2862 - val_loss: -0.3206 - val_IOU_calc: 0.2969
# Epoch 7/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.3164 - IOU_calc: 0.3150 - val_loss: -0.3388 - val_IOU_calc: 0.3127
# Epoch 8/50
# 94/94 [==============================] - 6s 67ms/sample - loss: -0.3204 - IOU_calc: 0.3214 - val_loss: -0.2808 - val_IOU_calc: 0.3140
# Epoch 9/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.3039 - IOU_calc: 0.3077 - val_loss: -0.3915 - val_IOU_calc: 0.4641
# Epoch 10/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.3403 - IOU_calc: 0.3469 - val_loss: -0.3330 - val_IOU_calc: 0.2835
# Epoch 11/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.3779 - IOU_calc: 0.3793 - val_loss: -0.4008 - val_IOU_calc: 0.5087
# Epoch 12/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.4176 - IOU_calc: 0.4160 - val_loss: -0.4057 - val_IOU_calc: 0.3493
# Epoch 13/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.4427 - IOU_calc: 0.4363 - val_loss: -0.3777 - val_IOU_calc: 0.3475
# Epoch 14/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.4970 - IOU_calc: 0.4953 - val_loss: -0.4936 - val_IOU_calc: 0.6196
# Epoch 15/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.5396 - IOU_calc: 0.5498 - val_loss: -0.5821 - val_IOU_calc: 0.6723
# Epoch 16/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.6672 - IOU_calc: 0.6750 - val_loss: -0.7227 - val_IOU_calc: 0.7789
# Epoch 17/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.7642 - IOU_calc: 0.7673 - val_loss: -0.6763 - val_IOU_calc: 0.7114
# Epoch 18/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.7890 - IOU_calc: 0.7883 - val_loss: -0.7692 - val_IOU_calc: 0.7635
# Epoch 19/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8086 - IOU_calc: 0.8083 - val_loss: -0.8165 - val_IOU_calc: 0.8188
# Epoch 20/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8065 - IOU_calc: 0.8005 - val_loss: -0.7705 - val_IOU_calc: 0.8459
# Epoch 21/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8291 - IOU_calc: 0.8285 - val_loss: -0.8056 - val_IOU_calc: 0.8486
# Epoch 22/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8359 - IOU_calc: 0.8329 - val_loss: -0.7894 - val_IOU_calc: 0.8574
# Epoch 23/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.8272 - IOU_calc: 0.8259 - val_loss: -0.7803 - val_IOU_calc: 0.7876
# Epoch 24/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8181 - IOU_calc: 0.8033 - val_loss: -0.8079 - val_IOU_calc: 0.8441
# Epoch 25/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8388 - IOU_calc: 0.8408 - val_loss: -0.7865 - val_IOU_calc: 0.7273
# Epoch 26/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8242 - IOU_calc: 0.8231 - val_loss: -0.8166 - val_IOU_calc: 0.8486
# Epoch 27/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8327 - IOU_calc: 0.8323 - val_loss: -0.7976 - val_IOU_calc: 0.7580
# Epoch 28/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8390 - IOU_calc: 0.8370 - val_loss: -0.8261 - val_IOU_calc: 0.7852
# Epoch 29/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.8291 - IOU_calc: 0.8314 - val_loss: -0.7877 - val_IOU_calc: 0.8505
# Epoch 30/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8403 - IOU_calc: 0.8436 - val_loss: -0.8123 - val_IOU_calc: 0.7356
# Epoch 31/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8403 - IOU_calc: 0.8391 - val_loss: -0.7662 - val_IOU_calc: 0.7697
# Epoch 32/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8429 - IOU_calc: 0.8414 - val_loss: -0.8013 - val_IOU_calc: 0.7887
# Epoch 33/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8426 - IOU_calc: 0.8437 - val_loss: -0.8103 - val_IOU_calc: 0.8544
# Epoch 34/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8454 - IOU_calc: 0.8445 - val_loss: -0.7824 - val_IOU_calc: 0.6969
# Epoch 35/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8391 - IOU_calc: 0.8413 - val_loss: -0.7856 - val_IOU_calc: 0.8481
# Epoch 36/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8444 - IOU_calc: 0.8396 - val_loss: -0.8143 - val_IOU_calc: 0.8822
# Epoch 37/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.8469 - IOU_calc: 0.8456 - val_loss: -0.7797 - val_IOU_calc: 0.7902
# Epoch 38/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.8450 - IOU_calc: 0.8484 - val_loss: -0.8050 - val_IOU_calc: 0.7723
# Epoch 39/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8498 - IOU_calc: 0.8461 - val_loss: -0.8058 - val_IOU_calc: 0.8394
# Epoch 40/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8403 - IOU_calc: 0.8393 - val_loss: -0.7498 - val_IOU_calc: 0.8221
# Epoch 41/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8367 - IOU_calc: 0.8321 - val_loss: -0.8008 - val_IOU_calc: 0.8645
# Epoch 42/50
# 94/94 [==============================] - 6s 66ms/sample - loss: -0.8499 - IOU_calc: 0.8521 - val_loss: -0.7988 - val_IOU_calc: 0.8137
# Epoch 43/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8496 - IOU_calc: 0.8472 - val_loss: -0.8020 - val_IOU_calc: 0.8275
# Epoch 44/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8530 - IOU_calc: 0.8524 - val_loss: -0.7886 - val_IOU_calc: 0.8026
# Epoch 45/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8544 - IOU_calc: 0.8515 - val_loss: -0.8018 - val_IOU_calc: 0.8438
# Epoch 46/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8564 - IOU_calc: 0.8505 - val_loss: -0.8205 - val_IOU_calc: 0.7441
# Epoch 47/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8542 - IOU_calc: 0.8563 - val_loss: -0.7808 - val_IOU_calc: 0.6946
# Epoch 48/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8479 - IOU_calc: 0.8470 - val_loss: -0.8286 - val_IOU_calc: 0.7846
# Epoch 49/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8512 - IOU_calc: 0.8567 - val_loss: -0.8159 - val_IOU_calc: 0.8790
# Epoch 50/50
# 94/94 [==============================] - 6s 65ms/sample - loss: -0.8583 - IOU_calc: 0.8581 - val_loss: -0.8055 - val_IOU_calc: 0.8629

# %% [markdown]
# ##  Courbe d'apprentissage

# %%
plt.figure(figsize=(20, 5))
plt.plot(model.history.history['loss'], label='Train loss')
plt.plot(model.history.history['val_loss'], label='Val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-da94e9042c51> in <module>()
#       1 plt.figure(figsize=(20, 5))
# ----> 2 plt.plot(model.history.history['loss'], label='Train loss')
#       3 plt.plot(model.history.history['val_loss'], label='Val loss')
#       4 plt.xlabel('Epochs')
#       5 plt.ylabel('Loss')
#
# AttributeError: 'NoneType' object has no attribute 'history'

# %%
plt.figure(figsize=(20, 5))
plt.plot(model.history.history['IOU_calc'], label='Train IOU')
plt.plot(model.history.history['val_IOU_calc'], label='Val IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-bdaaece9f453> in <module>()
#       1 plt.figure(figsize=(20, 5))
# ----> 2 plt.plot(model.history.history['IOU_calc'], label='Train IOU')
#       3 plt.plot(model.history.history['val_IOU_calc'], label='Val IOU')
#       4 plt.xlabel('Epochs')
#       5 plt.ylabel('IOU')
#
# AttributeError: 'NoneType' object has no attribute 'history'

# %% [markdown]
# ## Predict on testing data

# %%
predict = model.predict(X_test)

# %%
import numpy as np
import cv2


def predict_evaluation(pred, image, label):
    '''
    '''
    # transform gray image to rgb
    img = np.array(image, np.uint8)
    rgb_img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
    # scale pred and mask's pixel range to 0~255
    im_label = np.array(255*label, dtype=np.uint8)
    im_pred = np.array(255*pred, dtype=np.uint8)

    # transform both of them to rgb
    rgb_label = cv2.cvtColor(im_label, cv2.COLOR_GRAY2RGB)
    rgb_pred = cv2.cvtColor(im_pred, cv2.COLOR_GRAY2RGB)

    rgb_label[:, :, 1:3] = 0*rgb_label[:, :, 1:2]
    rgb_pred[:, :, 0] = 0*rgb_pred[:, :, 0]
    rgb_pred[:, :, 2] = 0*rgb_pred[:, :, 2]

    img_pred = cv2.addWeighted(rgb_img, 1, rgb_pred, 0.3, 0)
    img_label = cv2.addWeighted(rgb_img, 1, rgb_label, 0.3, 0)

    plt.figure(figsize=(10, 10))

    plt.subplot(1, 3, 1)
    plt.imshow(rgb_img)
    plt.title('Original image')
    plt.axis('off')
    plt.subplot(1, 3, 2)
    plt.imshow(img_pred)
    plt.title('Prediction')
    plt.axis('off')
    plt.subplot(1, 3, 3)
    plt.imshow(img_label)
    plt.title('Ground truth')
    plt.axis('off')

# %%
predict_evaluation(predict[0,:,:,0], X_test[0,:,:,0], y_test[0,:,:,0])

# %%
predict_evaluation(predict[1,:,:,0], X_test[1,:,:,0], y_test[1,:,:,0])

# %%
predict_evaluation(predict[2,:,:,0], X_test[2,:,:,0], y_test[2,:,:,0])

# %%
predict_evaluation(predict[3,:,:,0], X_test[3,:,:,0], y_test[3,:,:,0])

# %%
predict_evaluation(predict[4,:,:,0], X_test[4,:,:,0], y_test[4,:,:,0])

# %%
predict_evaluation(predict[5,:,:,0], X_test[5,:,:,0], y_test[5,:,:,0])

# %%
predict_evaluation(predict[6,:,:,0], X_test[6,:,:,0], y_test[6,:,:,0])

# %%
predict_evaluation(predict[7,:,:,0], X_test[7,:,:,0], y_test[7,:,:,0])

# %%
predict_evaluation(predict[8,:,:,0], X_test[8,:,:,0], y_test[8,:,:,0])

# %%
predict_evaluation(predict[9,:,:,0], X_test[9,:,:,0], y_test[9,:,:,0])

# %%
#probléme à signaler (chargement de l historique de learning)
